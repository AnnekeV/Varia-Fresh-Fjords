# %%
import xarray as xr

# %%
path_temp = "/Volumes/imau01/rapid/RACMO2.3p2/FGRN055/Downscaling_GR/Monthly/2023/t2m.2023.BN_RACMO2.3p2_ERA5_3h_FGRN055.1km.MM.nc.gz"

# %%
ds_t2m = xr.open_dataset(path_temp)

# %%
ds_t2m.t2m.isel(time=-1).plot(robust=True)

# %%
ds_snowmelt = xr.open_dataset('/Volumes/imau01/rapid/RACMO2.3p2/FGRN055/Downscaling_GR/Monthly/2023/snowmelt.2023.BN_RACMO2.3p2_ERA5_3h_FGRN055.1km.MM.nc.gz')

# %%
ds_snowmelt.snowmeltcorr.isel(time=-1).plot()
